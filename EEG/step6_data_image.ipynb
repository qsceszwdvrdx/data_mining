# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
df = pd.read_csv('C:/Users/user/Desktop/eeg/all_test_feature4.csv')
df1 = pd.read_csv('C:/Users/user/Desktop/eeg/all_feature3.csv')

# %%
df['relax'] = df['after'] - df['before']

# %%
f = df[df['id']=='f']
fv = f['after'].value_counts()
plt.pie(fv.values, labels=fv.index, autopct='%1.1f%%')
plt.axis('equal')  # 让饼图呈现正圆形
plt.show()

m = df[df['id']=='m']
mv = m['after'].value_counts()
plt.pie(mv.values, labels=mv.index, autopct='%1.1f%%')
plt.axis('equal')  # 让饼图呈现正圆形
plt.show()

p = df[df['id']=='p']
pv = p['after'].value_counts()
plt.pie(pv.values, labels=pv.index, autopct='%1.1f%%')
plt.axis('equal')  # 让饼图呈现正圆形
plt.show()

# %%
f = df[df['id']=='f']
fv = f['relax'].value_counts()
plt.pie(fv.values, labels=fv.index, autopct='%1.1f%%')
plt.axis('equal')  # 让饼图呈现正圆形
plt.show()

m = df[df['id']=='m']
mv = m['relax'].value_counts()
plt.pie(mv.values, labels=mv.index, autopct='%1.1f%%')
plt.axis('equal')  # 让饼图呈现正圆形
plt.show()

p = df[df['id']=='p']
pv = p['relax'].value_counts()
plt.pie(pv.values, labels=pv.index, autopct='%1.1f%%')
plt.axis('equal')  # 让饼图呈现正圆形
plt.show()

# %%
grid = sns.FacetGrid(df, col = "relax", hue = "relax", col_wrap=4)
grid.map(sns.scatterplot, df.index, "fft_IQR_aisle1_alpha")
grid.add_legend()
plt.show()

grid = sns.FacetGrid(df, col = "relax", hue = "relax", col_wrap=4)
grid.map(sns.scatterplot, df.index, "mean_aisle1_alpha")
grid.add_legend()
plt.show()

# %%
f = df[df['id']=='f']
grid = sns.FacetGrid(f, col = "relax", hue = "relax", col_wrap=4)
grid.map(sns.scatterplot, "index", "mean_1")
grid.add_legend()
plt.show()

m = df[df['id']=='m']
grid = sns.FacetGrid(m, col = "relax", hue = "relax", col_wrap=4)
grid.map(sns.scatterplot, "index", "mean_1")
grid.add_legend()
plt.show()

p = df[df['id']=='p']
grid = sns.FacetGrid(p, col = "relax", hue = "relax", col_wrap=4)
grid.map(sns.scatterplot, "index", "mean_1")
grid.add_legend()
plt.show()

# %%
f = df[df['id']=='f']
grid = sns.FacetGrid(f, col = "relax", hue = "relax", col_wrap=4)
grid.map(sns.scatterplot, "index", "energy_2")
grid.add_legend()
plt.show()

m = df[df['id']=='m']
grid = sns.FacetGrid(m, col = "relax", hue = "relax", col_wrap=4)
grid.map(sns.scatterplot, "index", "energy_2")
grid.add_legend()
plt.show()

p = df[df['id']=='p']
grid = sns.FacetGrid(p, col = "relax", hue = "relax", col_wrap=4)
grid.map(sns.scatterplot, "index", "energy_2")
grid.add_legend()
plt.show()

# %%
f = df[df['id']=='f']
grid = sns.FacetGrid(f, col = "after", hue = "after", col_wrap=4)
grid.map(sns.scatterplot, "index", "energy_1")
grid.add_legend()
plt.show()

m = df[df['id']=='m']
grid = sns.FacetGrid(m, col = "after", hue = "after", col_wrap=4)
grid.map(sns.scatterplot, "index", "energy_1")
grid.add_legend()
plt.show()

p = df[df['id']=='p']
grid = sns.FacetGrid(p, col = "after", hue = "after", col_wrap=4)
grid.map(sns.scatterplot, "index", "energy_1")
grid.add_legend()
plt.show()

# %%
f = df[df['id']=='f']
grid = sns.FacetGrid(f, col = "after", hue = "after", col_wrap=4)
grid.map(sns.scatterplot, "index", "mid_2")
grid.add_legend()
plt.show()

m = df[df['id']=='m']
grid = sns.FacetGrid(m, col = "after", hue = "after", col_wrap=4)
grid.map(sns.scatterplot, "index", "mid_2")
grid.add_legend()
plt.show()

p = df[df['id']=='p']
grid = sns.FacetGrid(p, col = "after", hue = "after", col_wrap=4)
grid.map(sns.scatterplot, "index", "mid_2")
grid.add_legend()
plt.show()

# %%
fig = px.box(df, x="relax", y="fft_IQR_aisle1_alpha",points='all',width=600)
fig.show()
fig = px.box(df, x="relax", y="mean_aisle1_alpha",points='all',width=600)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 fig = px.box(df, x="relax", y="fft_IQR_aisle1_alpha",points='all',width=600)
# ----> 2 fig.show()
#       3 fig = px.box(df, x="relax", y="mean_aisle1_alpha",points='all',width=600)
#       4 fig.show()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\plotly\basedatatypes.py:3390, in BaseFigure.show(self, *args, **kwargs)
#    3357 """
#    3358 Show a figure using either the default renderer(s) or the renderer(s)
#    3359 specified by the renderer argument
#    (...)
#    3386 None
#    3387 """
#    3388 import plotly.io as pio
# -> 3390 return pio.show(self, *args, **kwargs)
#
# ...

# %%
# !pip install --upgrade nbformat

# %%
import plotly.express as px
fig = px.bar(x=['a','b','c'],y=[1,3,2])
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 3
#       1 import plotly.express as px
#       2 fig = px.bar(x=['a','b','c'],y=[1,3,2])
# ----> 3 fig.show()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\plotly\basedatatypes.py:3390, in BaseFigure.show(self, *args, **kwargs)
#    3357 """
#    3358 Show a figure using either the default renderer(s) or the renderer(s)
#    3359 specified by the renderer argument
#    (...)
#    3386 None
#    3387 """
#    3388 import plotly.io as pio
# -> 3390 return pio.show(self, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\plotly\io\_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
# ...
