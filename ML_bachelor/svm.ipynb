# %% [markdown]
# 匯入資料

# %%
import pandas as pd
import numpy as np
from sklearn.svm import SVC
import matplotlib.pyplot as plt
from sklearn.datasets import load_wine
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
wine = load_wine()
feature = pd.DataFrame(wine['data'],columns = wine['feature_names'])
target = pd.DataFrame(wine['target'],columns = ['class'])
data = pd.concat([feature,target],axis = 1)

# %%
data.head(2)
# Out:
#    alcohol  malic_acid   ash  ...  od280/od315_of_diluted_wines  proline  class
# 0    14.23        1.71  2.43  ...                          3.92   1065.0      0
# 1    13.20        1.78  2.14  ...                          3.40   1050.0      0
#
# [2 rows x 14 columns]

# %%
df_wine = data
X = df_wine[['alcohol','malic_acid']].values 
y = df_wine['class'].values

# %% [markdown]
# 區分 train/test data

# %%
#random_state=none 隨機取樣
# stratify=y 有設定y才會分配比較平均
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size =0.3,random_state=100, stratify=y)

# %% [markdown]
# 標準化

# %%
sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

# %% [markdown]
# 畫圖函式

# %%
from matplotlib.colors import ListedColormap

def plot_decision_regions(X, y, classifier, test_idx=None, resolution=0.02):

    # setup marker generator and color map
    markers = ('s', 'x', 'o', '^', 'v')
    colors = ('orange', 'cornflowerblue', 'palegreen', 'gray', 'cyan')
    cmap = ListedColormap(colors[:len(np.unique(y))])

    # plot the decision surface
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
                           np.arange(x2_min, x2_max, resolution))
    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    Z = Z.reshape(xx1.shape)
    plt.contourf(xx1, xx2, Z, alpha=0.4, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())

    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0], 
                    y=X[y == cl, 1],
                    alpha=0.6, 
                    c=cmap(idx),
                    edgecolor='black',
                    marker=markers[idx], 
                    label=cl)

    # highlight test samples
    if test_idx:
        # plot all samples
        if not versiontuple(np.__version__) >= versiontuple('1.9.0'):
            X_test, y_test = X[list(test_idx), :], y[list(test_idx)]
            warnings.warn('Please update to NumPy 1.9.0 or newer')
        else:
            X_test, y_test = X[test_idx, :], y[test_idx]

        plt.scatter(X_test[:, 0],
                    X_test[:, 1],
                    c='',
                    alpha=1.0,
                    edgecolor='black',
                    linewidths=1,
                    marker='o',
                    s=55, label='test set')

# %% [markdown]
# SVM模型

# %%
svm = SVC(kernel='linear') 
svm.fit(X_train_std,y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
# svm.predict(X_test_std)

# %%
# svm.predict_proba(X_test_std)

# %%
plot_decision_regions(X_train_std, y_train, classifier=svm)
plt.xlabel('alcohol [standardized]')
plt.ylabel('malic_acid [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
svm.score(X_test_std,y_test)
# Out:
# 0.7222222222222222

# %% [markdown]
# RBF kernel

# %%
gamma = [0.1*x for x in range(1,11) ]
# gamma

# %%
rbf_score=[]

for g in gamma:  
  svm = SVC(kernel='rbf', gamma=g)
  svm.fit(X_train_std,y_train)
  score = svm.score(X_test_std,y_test)
  rbf_score.append(score)

# %%
plt.plot(gamma,rbf_score)
plt.xlabel('gamma of Polynomial kernel svm')
plt.ylabel('svm score')
# Out:
# Text(0, 0.5, 'svm score')

# %%
rbf_score
# Out:
# [0.7592592592592593,
#  0.7777777777777778,
#  0.7777777777777778,
#  0.7777777777777778,
#  0.7962962962962963,
#  0.7777777777777778,
#  0.7777777777777778,
#  0.7962962962962963,
#  0.7962962962962963,
#  0.7962962962962963]

# %%
for g in gamma:  
  svm = SVC(kernel='rbf', gamma=g)
  svm.fit(X_train_std,y_train)
  plot_decision_regions(X_train_std, y_train, classifier=svm)

  plt.xlabel('alcohol [standardized]')
  plt.ylabel('malic_acid [standardized]')
  plt.legend(loc='upper left')
  plt.tight_layout()
  plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ...

# %% [markdown]
# 範圍拉大

# %%
gamma = [10**x for x in range(-4,5) ]
gamma
# Out:
# [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000, 10000]

# %%
rbf_score=[]

for g in gamma:  
  svm = SVC(kernel='rbf', gamma=g)
  svm.fit(X_train_std,y_train)
  score = svm.score(X_test_std,y_test)
  rbf_score.append(score)

# %%
rbf_score
# Out:
# [0.3888888888888889,
#  0.3888888888888889,
#  0.7037037037037037,
#  0.7592592592592593,
#  0.7962962962962963,
#  0.7777777777777778,
#  0.6481481481481481,
#  0.4444444444444444,
#  0.4074074074074074]

# %%
for g in gamma:  
  svm = SVC(kernel='rbf', gamma=g)
  svm.fit(X_train_std,y_train)
  plot_decision_regions(X_train_std, y_train, classifier=svm)
  
  plt.title('gamma='+ str(g))
  plt.xlabel('alcohol [standardized]')
  plt.ylabel('malic_acid [standardized]')
  plt.legend(loc='upper left')
  plt.tight_layout()
  plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ...

# %% [markdown]
# RBF SVM C

# %%
C = [10**x for x in range(-3,3) ]
C
# Out:
# [0.001, 0.01, 0.1, 1, 10, 100]

# %%
rbf_score=[]

for c in C:  
  svm = SVC(kernel='rbf',C=c)
  svm.fit(X_train_std,y_train)
  score = svm.score(X_test_std,y_test)
  rbf_score.append(score)

# %%
rbf_score
# Out:
# [0.3888888888888889,
#  0.3888888888888889,
#  0.7777777777777778,
#  0.7962962962962963,
#  0.8148148148148148,
#  0.7777777777777778]

# %%
for c in C:  
  svm = SVC(kernel='rbf',C=c)
  svm.fit(X_train_std,y_train)
  plot_decision_regions(X_train_std, y_train, classifier=svm)
  
  plt.title('C='+ str(c))
  plt.xlabel('alcohol [standardized]')
  plt.ylabel('malic_acid [standardized]')
  plt.legend(loc='upper left')
  plt.tight_layout()
  plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ...

# %% [markdown]
# C從0.1到1之間選擇

# %%
C = [0.1*x for x in range(1,11)]
# C

# %%
rbf_score=[]

for c in C:  
  svm = SVC(kernel='rbf',C=c)
  svm.fit(X_train_std,y_train)
  score = svm.score(X_test_std,y_test)
  rbf_score.append(score)

# %%
rbf_score
# Out:
# [0.7777777777777778,
#  0.7592592592592593,
#  0.7777777777777778,
#  0.7592592592592593,
#  0.7592592592592593,
#  0.7777777777777778,
#  0.7962962962962963,
#  0.7962962962962963,
#  0.7962962962962963,
#  0.7962962962962963]

# %%
plt.plot(C,rbf_score)
plt.xlabel('c_value of rbf kernel svm')
plt.ylabel('svm score')
# Out:
# Text(0, 0.5, 'svm score')

# %%
svm = SVC(kernel='rbf',C=0.8)
svm.fit(X_train_std,y_train)
plot_decision_regions(X_train_std, y_train, classifier=svm)

plt.title('C=0.8')
plt.xlabel('alcohol [standardized]')
plt.ylabel('malic_acid [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# 最後結果

# %%
better_gamma=[0.5,0.8,0.9,1]
better_c=[0.7,0.8,0.9,1]

# %%
for g in better_gamma:
  for c in better_c:
    svm = SVC(kernel='rbf',gamma=g,C=c)
    svm.fit(X_train_std,y_train)
    score = svm.score(X_test_std,y_test)
    rbf_score.append(score)

# %%
rbf_score
# Out:
# [0.7592592592592593,
#  0.7777777777777778,
#  0.7777777777777778,
#  0.7777777777777778,
#  0.7962962962962963,
#  0.7777777777777778,
#  0.7777777777777778,
#  0.7962962962962963,
#  0.7962962962962963,
#  0.7962962962962963,
#  0.7962962962962963,
#  0.7962962962962963,
#  0.7962962962962963,
#  0.7962962962962963,
#  0.7962962962962963,
#  0.7962962962962963,
#  0.7962962962962963,
#  0.7962962962962963,
#  0.7962962962962963,
#  0.7962962962962963,
#  0.7962962962962963,
#  0.7962962962962963,
#  0.7962962962962963,
#  0.7962962962962963,
#  0.7962962962962963,
#  0.7962962962962963]

# %%
svm = SVC(kernel='rbf',gamma=1,C=1)
svm.fit(X_train_std,y_train)
plot_decision_regions(X_train_std, y_train, classifier=svm)

plt.title('C=1 gamma=1')
plt.xlabel('alcohol [standardized]')
plt.ylabel('malic_acid [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# Polynomial kernel SVC

# %%
Deg = [x for x in range(1,10)]
Deg
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
Poly_score=[]

for d in Deg:  
  svm = SVC(kernel='poly', degree=d)
  svm.fit(X_train_std,y_train)
  score = svm.score(X_test_std,y_test)
  Poly_score.append(score)

# %%
plt.plot(Deg,Poly_score)
plt.xlabel('degree of Polynomial kernel svm')
plt.ylabel('svm score')
# Out:
# Text(0, 0.5, 'svm score')

# %%
Poly_score
# Out:
# [0.7407407407407407,
#  0.6111111111111112,
#  0.7592592592592593,
#  0.5555555555555556,
#  0.7037037037037037,
#  0.5,
#  0.6111111111111112,
#  0.5,
#  0.5925925925925926]

# %%
#degree=1,跟linear是同樣的東西
svm = SVC(kernel='poly', degree=3)
svm.fit(X_train_std,y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='poly',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
plot_decision_regions(X_train_std, y_train, classifier=svm)
plt.title('degree=3')
plt.xlabel('alcohol [standardized]')
plt.ylabel('malic_acid [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
for d in Deg:
  svm = SVC(kernel='poly', degree=d)
  svm.fit(X_train_std,y_train)
  plot_decision_regions(X_train_std, y_train, classifier=svm)

  plt.title('degree='+str(d))
  plt.xlabel('alcohol [standardized]')
  plt.ylabel('malic_acid [standardized]')
  plt.legend(loc='upper left')
  plt.tight_layout()
  plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ...
