# %% [markdown]
# # open

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
daily = pd.read_csv('/content/drive/MyDrive/碩一下/多變量分析/data/merge/daily.csv')
heartrate = pd.read_csv('/content/drive/MyDrive/碩一下/多變量分析/data/merge/heartrate.csv')
epoch = pd.read_csv('/content/drive/MyDrive/碩一下/多變量分析/data/merge/epoch.csv')
act = pd.read_csv('/content/drive/MyDrive/碩一下/多變量分析/data/merge/act.csv')
sleep = pd.read_csv('/content/drive/MyDrive/碩一下/多變量分析/data/merge/sleep.csv')
sleeplevel = pd.read_csv('/content/drive/MyDrive/碩一下/多變量分析/data/merge/sleeplevel.csv')
stress = pd.read_csv('/content/drive/MyDrive/碩一下/多變量分析/data/merge/stress.csv')
stresslevel = pd.read_csv('/content/drive/MyDrive/碩一下/多變量分析/data/merge/stresslevel.csv')

# %% [markdown]
# # daily

# %%
daily.head()
# Out:
#                    summaryId calendarDate activityType  activeKilocalories  \
# 0  x4380d96-62262c00-10464-6   2022-03-08      WALKING                  48
# 1  x4380d96-62262c00-15180-6   2022-03-08      WALKING                  49
# 2  x4380d96-62277d80-13290-6   2022-03-09      WALKING                 109
# 3  x4380d96-62277d80-15180-6   2022-03-09      WALKING                 111
# 4   x4380d96-6228cf00-a848-6   2022-03-10      WALKING                 242
#
#    bmrKilocalories  steps  distanceInMeters  durationInSeconds  \
# 0             1185    369             230.0              66660
# 1             1537    407             258.0              86400
# 2             1396   1806            1218.0              78480
# 3             1537   1854            1253.0              86400
# 4              766   3432            2280.0              43080
#
#    activeTimeInSeconds  startTimeInSeconds  ...  averageStressLevel  \
# ...

# %%
daily.columns
# Out:
# Index(['summaryId', 'calendarDate', 'activityType', 'activeKilocalories',
#        'bmrKilocalories', 'steps', 'distanceInMeters', 'durationInSeconds',
#        'activeTimeInSeconds', 'startTimeInSeconds', 'startTimeOffsetInSeconds',
#        'moderateIntensityDurationInSeconds',
#        'vigorousIntensityDurationInSeconds', 'floorsClimbed',
#        'minHeartRateInBeatsPerMinute', 'maxHeartRateInBeatsPerMinute',
#        'averageHeartRateInBeatsPerMinute', 'restingHeartRateInBeatsPerMinute',
#        'stepsGoal', 'intensityDurationGoalInSeconds', 'floorsClimbedGoal',
#        'averageStressLevel', 'maxStressLevel', 'stressDurationInSeconds',
#        'restStressDurationInSeconds', 'activityStressDurationInSeconds',
#        'lowStressDurationInSeconds', 'mediumStressDurationInSeconds',
#        'highStressDurationInSeconds', 'stressQualifier', 'id'],
#       dtype='object')

# %% [markdown]
# ## step / distance / floor

# %% [markdown]
# ### step

# %%
step = daily[['id','calendarDate','steps']]

# %%
step1 = step[step['id']==1].groupby('calendarDate')['steps'].sum().to_frame().reset_index()
step2 = step[step['id']==2].groupby('calendarDate')['steps'].sum().to_frame().reset_index()
step3 = step[step['id']==3].groupby('calendarDate')['steps'].sum().to_frame().reset_index()
step4 = step[step['id']==4].groupby('calendarDate')['steps'].sum().to_frame().reset_index()
step5 = step[step['id']==5].groupby('calendarDate')['steps'].sum().to_frame().reset_index()
step6 = step[step['id']==6].groupby('calendarDate')['steps'].sum().to_frame().reset_index()
step7 = step[step['id']==7].groupby('calendarDate')['steps'].sum().to_frame().reset_index()
step8 = step[step['id']==8].groupby('calendarDate')['steps'].sum().to_frame().reset_index()
step9 = step[step['id']==9].groupby('calendarDate')['steps'].sum().to_frame().reset_index()
step10 = step[step['id']==10].groupby('calendarDate')['steps'].sum().to_frame().reset_index()
step11 = step[step['id']==11].groupby('calendarDate')['steps'].sum().to_frame().reset_index()
step12 = step[step['id']==12].groupby('calendarDate')['steps'].sum().to_frame().reset_index()
step13 = step[step['id']==13].groupby('calendarDate')['steps'].sum().to_frame().reset_index()
step14 = step[step['id']==14].groupby('calendarDate')['steps'].sum().to_frame().reset_index()
step15 = step[step['id']==15].groupby('calendarDate')['steps'].sum().to_frame().reset_index()
step16 = step[step['id']==16].groupby('calendarDate')['steps'].sum().to_frame().reset_index()
step17 = step[step['id']==17].groupby('calendarDate')['steps'].sum().to_frame().reset_index()

# %% [markdown]
# ### distance

# %%
distance = daily[['id','calendarDate','distanceInMeters']]

# %%
distance1 = distance[distance['id']==1].groupby('calendarDate')['distanceInMeters'].sum().to_frame().reset_index()
distance2 = distance[distance['id']==2].groupby('calendarDate')['distanceInMeters'].sum().to_frame().reset_index()
distance3 = distance[distance['id']==3].groupby('calendarDate')['distanceInMeters'].sum().to_frame().reset_index()
distance4 = distance[distance['id']==4].groupby('calendarDate')['distanceInMeters'].sum().to_frame().reset_index()
distance5 = distance[distance['id']==5].groupby('calendarDate')['distanceInMeters'].sum().to_frame().reset_index()
distance6 = distance[distance['id']==6].groupby('calendarDate')['distanceInMeters'].sum().to_frame().reset_index()
distance7 = distance[distance['id']==7].groupby('calendarDate')['distanceInMeters'].sum().to_frame().reset_index()
distance8 = distance[distance['id']==8].groupby('calendarDate')['distanceInMeters'].sum().to_frame().reset_index()
distance9 = distance[distance['id']==9].groupby('calendarDate')['distanceInMeters'].sum().to_frame().reset_index()
distance10 = distance[distance['id']==10].groupby('calendarDate')['distanceInMeters'].sum().to_frame().reset_index()
distance11 = distance[distance['id']==11].groupby('calendarDate')['distanceInMeters'].sum().to_frame().reset_index()
distance12 = distance[distance['id']==12].groupby('calendarDate')['distanceInMeters'].sum().to_frame().reset_index()
distance13 = distance[distance['id']==13].groupby('calendarDate')['distanceInMeters'].sum().to_frame().reset_index()
distance14 = distance[distance['id']==14].groupby('calendarDate')['distanceInMeters'].sum().to_frame().reset_index()
distance15 = distance[distance['id']==15].groupby('calendarDate')['distanceInMeters'].sum().to_frame().reset_index()
distance16 = distance[distance['id']==16].groupby('calendarDate')['distanceInMeters'].sum().to_frame().reset_index()
distance17 = distance[distance['id']==17].groupby('calendarDate')['distanceInMeters'].sum().to_frame().reset_index()

# %%
step1 = step1.merge(distance1,how='left')
step2 = step2.merge(distance2,how='left')
step3 = step3.merge(distance3,how='left')
step4 = step4.merge(distance4,how='left')
step5 = step5.merge(distance5,how='left')
step6 = step6.merge(distance6,how='left')
step7 = step7.merge(distance7,how='left')
step8 = step8.merge(distance8,how='left')
step9 = step9.merge(distance9,how='left')
step10 = step10.merge(distance10,how='left')
step11 = step11.merge(distance11,how='left')
step12 = step12.merge(distance12,how='left')
step13 = step13.merge(distance13,how='left')
step14 = step14.merge(distance14,how='left')
step15 = step15.merge(distance15,how='left')
step16 = step16.merge(distance16,how='left')
step17 = step17.merge(distance17,how='left')

# %% [markdown]
# ### floor

# %%
floor = daily[['id','calendarDate','floorsClimbed']]

# %%
floor1 = floor[floor['id']==1].groupby('calendarDate')['floorsClimbed'].sum().to_frame().reset_index()
floor2 = floor[floor['id']==2].groupby('calendarDate')['floorsClimbed'].sum().to_frame().reset_index()
floor3 = floor[floor['id']==3].groupby('calendarDate')['floorsClimbed'].sum().to_frame().reset_index()
floor4 = floor[floor['id']==4].groupby('calendarDate')['floorsClimbed'].sum().to_frame().reset_index()
floor5 = floor[floor['id']==5].groupby('calendarDate')['floorsClimbed'].sum().to_frame().reset_index()
floor6 = floor[floor['id']==6].groupby('calendarDate')['floorsClimbed'].sum().to_frame().reset_index()
floor7 = floor[floor['id']==7].groupby('calendarDate')['floorsClimbed'].sum().to_frame().reset_index()
floor8 = floor[floor['id']==8].groupby('calendarDate')['floorsClimbed'].sum().to_frame().reset_index()
floor9 = floor[floor['id']==9].groupby('calendarDate')['floorsClimbed'].sum().to_frame().reset_index()
floor10 = floor[floor['id']==10].groupby('calendarDate')['floorsClimbed'].sum().to_frame().reset_index()
floor11 = floor[floor['id']==11].groupby('calendarDate')['floorsClimbed'].sum().to_frame().reset_index()
floor12 = floor[floor['id']==12].groupby('calendarDate')['floorsClimbed'].sum().to_frame().reset_index()
floor13 = floor[floor['id']==13].groupby('calendarDate')['floorsClimbed'].sum().to_frame().reset_index()
floor14 = floor[floor['id']==14].groupby('calendarDate')['floorsClimbed'].sum().to_frame().reset_index()
floor15 = floor[floor['id']==15].groupby('calendarDate')['floorsClimbed'].sum().to_frame().reset_index()
floor16 = floor[floor['id']==16].groupby('calendarDate')['floorsClimbed'].sum().to_frame().reset_index()
floor17 = floor[floor['id']==17].groupby('calendarDate')['floorsClimbed'].sum().to_frame().reset_index()

# %%
step1 = step1.merge(floor1,how='left')
step2 = step2.merge(floor2,how='left')
step3 = step3.merge(floor3,how='left')
step4 = step4.merge(floor4,how='left')
step5 = step5.merge(floor5,how='left')
step6 = step6.merge(floor6,how='left')
step7 = step7.merge(floor7,how='left')
step8 = step8.merge(floor8,how='left')
step9 = step9.merge(floor9,how='left')
step10 = step10.merge(floor10,how='left')
step11 = step11.merge(floor11,how='left')
step12 = step12.merge(floor12,how='left')
step13 = step13.merge(floor13,how='left')
step14 = step14.merge(floor14,how='left')
step15 = step15.merge(floor15,how='left')
step16 = step16.merge(floor16,how='left')
step17 = step17.merge(floor17,how='left')

# %%
all = [step1,step2,step3,step4,step5,step6,step7,step8,step9,step10,step11,step12,step13,step14,step15,step16,step17]

# %%
def check_steps(x):
  if x >= 10000:
    return 3
  elif x >= 6000:
    return 2
  else:
    return 1

# %%
step1['check'] =  step1['steps'].map(check_steps)
step2['check'] =  step2['steps'].map(check_steps)
step3['check'] =  step3['steps'].map(check_steps)
step4['check'] =  step4['steps'].map(check_steps)
step5['check'] =  step5['steps'].map(check_steps)
step6['check'] =  step6['steps'].map(check_steps)
step7['check'] =  step7['steps'].map(check_steps)
step8['check'] =  step8['steps'].map(check_steps)
step9['check'] =  step9['steps'].map(check_steps)
step10['check'] =  step10['steps'].map(check_steps)
step11['check'] =  step11['steps'].map(check_steps)
step12['check'] =  step12['steps'].map(check_steps)
step13['check'] =  step13['steps'].map(check_steps)
step14['check'] =  step14['steps'].map(check_steps)
step15['check'] =  step15['steps'].map(check_steps)
step16['check'] =  step16['steps'].map(check_steps)
step17['check'] =  step17['steps'].map(check_steps)

# %%
step17.head()
# Out:
#   calendarDate  steps  distanceInMeters  floorsClimbed  check
# 0   2022-03-08   9044            6290.0             30      2
# 1   2022-03-09  16476           12247.0              0      3
# 2   2022-03-10  20042           14106.0             30      3
# 3   2022-03-11   5029            3586.0             10      1
# 4   2022-03-12  10159            7246.0              8      3

# %%
for i in range(17):
  print('id '+str(i+1))
  print(all[i]['check'].value_counts())

# %%
mean_steps=[]

for i in range(len(all)):
  mean_steps.append(all[i]['steps'].mean())

# %%
print([round(i,1) for i in mean_steps])
# Out:
# [3884.1, 14171.5, 6216.6, 7534.1, 8668.5, 8608.7, 7127.0, 3440.7, 6137.9, 279.6, 8609.9, 6218.1, 5489.7, 7836.7, 6883.1, 4069.0, 7607.7]

# %%
data1 = [3884.1,6216.6,3440.7,279.6,7836.7, 6883.1, 4069.0, 7607.7]
data2 = [14171.5,8608.7,7534.1, 8668.5]
data3 = [7127.0, 6137.9,8609.9, 6218.1, 5489.7]

import scipy.stats
scipy.stats.f_oneway(dat1, dat2, data3)
# Out:
# F_onewayResult(statistic=153.522143226958, pvalue=2.8312723456620517e-09)

# %%
print(scipy.stats.f_oneway(dat1, dat2))
print(scipy.stats.f_oneway(dat2, data3))
# Out:
# F_onewayResult(statistic=28.66792955881228, pvalue=0.000682366248357892)
# F_onewayResult(statistic=188.30634395160553, pvalue=2.4378312240160683e-07)

# %% [markdown]
# ### fig

# %%
for x in range(len(all)):
  i=all[x]
  print('id = '+str(x+1))
  plt.plot(i['steps'],label='steps')
  plt.plot(i['distanceInMeters'],label='distance')
  plt.legend(loc='best')
  plt.tight_layout()
  plt.show()

# %% [markdown]
# # heartrate

# %%
heartrate.head(3)
# Out:
#                   summaryId  startTimeInSeconds  TimeInSeconds  heartrate  id
# 0  x39d29af-6272a300-38f4-6          1651680000             15         66   5
# 1  x39d29af-6272a300-38f4-6          1651680000             30         66   5
# 2  x39d29af-6272a300-38f4-6          1651680000             45         66   5

# %%
def cut_time(x):
  if x>=25200 and x<=54000:
    return 'rest'
  else:
    return 'daily'

# %%
cut_time(3600)
# Out:
# 'rest'

# %%
heartrate['cut_time'] =  heartrate['TimeInSeconds'].map(cut_time)

# %% [markdown]
# id=16 沒有心跳資料

# %%
heartrate1 = heartrate[heartrate['id']==1].reset_index()
heartrate2 = heartrate[heartrate['id']==2].reset_index()
heartrate3 = heartrate[heartrate['id']==3].reset_index()
heartrate4 = heartrate[heartrate['id']==4].reset_index()
heartrate5 = heartrate[heartrate['id']==5].reset_index()
heartrate6 = heartrate[heartrate['id']==6].reset_index()
heartrate7 = heartrate[heartrate['id']==7].reset_index()
heartrate8 = heartrate[heartrate['id']==8].reset_index()
heartrate9 = heartrate[heartrate['id']==9].reset_index()
heartrate10 = heartrate[heartrate['id']==10].reset_index()
heartrate11 = heartrate[heartrate['id']==11].reset_index()
heartrate12 = heartrate[heartrate['id']==12].reset_index()
heartrate13 = heartrate[heartrate['id']==13].reset_index()
heartrate14 = heartrate[heartrate['id']==14].reset_index()
heartrate15 = heartrate[heartrate['id']==15].reset_index()
heartrate17 = heartrate[heartrate['id']==17].reset_index()

# %%
heartrates = [heartrate1,heartrate2,heartrate3,heartrate4,heartrate5,heartrate6,heartrate7,heartrate8,
        heartrate9,heartrate10,heartrate11,heartrate12,heartrate13,heartrate14,heartrate15,heartrate17]

# %%
date=[]
date.append(list(set(heartrate1['startTimeInSeconds'])))
date.append(list(set(heartrate2['startTimeInSeconds'])))
date.append(list(set(heartrate3['startTimeInSeconds'])))
date.append(list(set(heartrate4['startTimeInSeconds'])))
date.append(list(set(heartrate5['startTimeInSeconds'])))
date.append(list(set(heartrate6['startTimeInSeconds'])))
date.append(list(set(heartrate7['startTimeInSeconds'])))
date.append(list(set(heartrate8['startTimeInSeconds'])))
date.append(list(set(heartrate9['startTimeInSeconds'])))
date.append(list(set(heartrate10['startTimeInSeconds'])))
date.append(list(set(heartrate11['startTimeInSeconds'])))
date.append(list(set(heartrate12['startTimeInSeconds'])))
date.append(list(set(heartrate13['startTimeInSeconds'])))
date.append(list(set(heartrate14['startTimeInSeconds'])))
date.append(list(set(heartrate15['startTimeInSeconds'])))
date.append(list(set(heartrate17['startTimeInSeconds'])))

# %%
print('ID1')
print('rest_mean = '+str(round(heartrate1[(heartrate1['startTimeInSeconds']==1650384000) & (heartrate1['cut_time']=='rest')]['heartrate'].mean(),1)))
print('daily_mean = '+str(round(heartrate1[(heartrate1['startTimeInSeconds']==1650384000) & (heartrate1['cut_time']=='daily')]['heartrate'].mean(),1)))
print('ID2')
print('rest_mean = '+str(round(heartrate2[(heartrate2['startTimeInSeconds']==1651507200) & (heartrate2['cut_time']=='rest')]['heartrate'].mean(),1)))
print('daily_mean = '+str(round(heartrate2[(heartrate2['startTimeInSeconds']==1651507200) & (heartrate2['cut_time']=='daily')]['heartrate'].mean(),1)))
print('ID3')
print('rest_mean = '+str(round(heartrate3[(heartrate3['startTimeInSeconds']==1650643200) & (heartrate3['cut_time']=='rest')]['heartrate'].mean(),1)))
print('daily_mean = '+str(round(heartrate3[(heartrate3['startTimeInSeconds']==1650643200) & (heartrate3['cut_time']=='daily')]['heartrate'].mean(),1)))
print('ID4')
print('rest_mean = '+str(round(heartrate4[(heartrate4['startTimeInSeconds']==1651507200) & (heartrate4['cut_time']=='rest')]['heartrate'].mean(),1)))
print('daily_mean = '+str(round(heartrate4[(heartrate4['startTimeInSeconds']==1651507200) & (heartrate4['cut_time']=='daily')]['heartrate'].mean(),1)))
print('ID5')
print('rest_mean = '+str(round(heartrate5[(heartrate5['startTimeInSeconds']==1651593600) & (heartrate5['cut_time']=='rest')]['heartrate'].mean(),1)))
print('daily_mean = '+str(round(heartrate5[(heartrate5['startTimeInSeconds']==1651593600) & (heartrate5['cut_time']=='daily')]['heartrate'].mean(),1)))
print('ID6')
print('rest_mean = '+str(round(heartrate6[(heartrate6['startTimeInSeconds']==1650988800) & (heartrate6['cut_time']=='rest')]['heartrate'].mean(),1)))
print('daily_mean = '+str(round(heartrate6[(heartrate6['startTimeInSeconds']==1650988800) & (heartrate6['cut_time']=='daily')]['heartrate'].mean(),1)))
print('ID7')
print('rest_mean = '+str(round(heartrate7[(heartrate7['startTimeInSeconds']==1651507200) & (heartrate7['cut_time']=='rest')]['heartrate'].mean(),1)))
print('daily_mean = '+str(round(heartrate7[(heartrate7['startTimeInSeconds']==1651507200) & (heartrate7['cut_time']=='daily')]['heartrate'].mean(),1)))
print('ID8')
print('rest_mean = '+str(round(heartrate8[(heartrate8['startTimeInSeconds']==1651507200) & (heartrate8['cut_time']=='rest')]['heartrate'].mean(),1)))
print('daily_mean = '+str(round(heartrate8[(heartrate8['startTimeInSeconds']==1651507200) & (heartrate8['cut_time']=='daily')]['heartrate'].mean(),1)))
print('ID11')
print('rest_mean = '+str(round(heartrate11[(heartrate11['startTimeInSeconds']==1650988800) & (heartrate11['cut_time']=='rest')]['heartrate'].mean(),1)))
print('daily_mean = '+str(round(heartrate11[(heartrate11['startTimeInSeconds']==1650988800) & (heartrate11['cut_time']=='daily')]['heartrate'].mean(),1)))
print('ID12')
print('rest_mean = '+str(round(heartrate12[(heartrate12['startTimeInSeconds']==1651161600) & (heartrate12['cut_time']=='rest')]['heartrate'].mean(),1)))
print('daily_mean = '+str(round(heartrate12[(heartrate12['startTimeInSeconds']==1651161600) & (heartrate12['cut_time']=='daily')]['heartrate'].mean(),1)))
print('ID13')
print('rest_mean = '+str(round(heartrate13[(heartrate13['startTimeInSeconds']==1651334400) & (heartrate13['cut_time']=='rest')]['heartrate'].mean(),1)))
print('daily_mean = '+str(round(heartrate13[(heartrate13['startTimeInSeconds']==1651334400) & (heartrate13['cut_time']=='daily')]['heartrate'].mean(),1)))
print('ID14')
print('rest_mean = '+str(round(heartrate14[(heartrate14['startTimeInSeconds']==1651507200) & (heartrate14['cut_time']=='rest')]['heartrate'].mean(),1)))
print('daily_mean = '+str(round(heartrate14[(heartrate14['startTimeInSeconds']==1651507200) & (heartrate14['cut_time']=='daily')]['heartrate'].mean(),1)))
print('ID15')
print('rest_mean = '+str(round(heartrate15[(heartrate15['startTimeInSeconds']==1651507200) & (heartrate15['cut_time']=='rest')]['heartrate'].mean(),1)))
print('daily_mean = '+str(round(heartrate15[(heartrate15['startTimeInSeconds']==1651507200) & (heartrate15['cut_time']=='daily')]['heartrate'].mean(),1)))
print('ID17')
print('rest_mean = '+str(round(heartrate17[(heartrate17['startTimeInSeconds']==1651075200) & (heartrate17['cut_time']=='rest')]['heartrate'].mean(),1)))
print('daily_mean = '+str(round(heartrate17[(heartrate17['startTimeInSeconds']==1651075200) & (heartrate17['cut_time']=='daily')]['heartrate'].mean(),1)))
# Out:
# ID1
# rest_mean = 75.2
# daily_mean = 79.4
# ID2
# rest_mean = 77.8
# daily_mean = 73.9
# ID3
# rest_mean = 67.9
# daily_mean = 73.3
# ID4
# rest_mean = 56.7
# daily_mean = 64.0
# ID5
# rest_mean = 66.6
# daily_mean = 62.9
# ID6
# rest_mean = 62.2
# daily_mean = 75.9
# ID7
# rest_mean = 88.9
# daily_mean = 92.2
# ID8
# rest_mean = 59.5
# daily_mean = 67.0
# ID11
# rest_mean = 92.0
# daily_mean = 86.5
# ID12
# rest_mean = 112.8
# daily_mean = 109.7
# ID13
# rest_mean = 67.2
# daily_mean = 64.8
# ID14
# rest_mean = 63.1
# daily_mean = 74.8
# ID15
# rest_mean = 78.6
# daily_mean = 72.5
# ID17
# rest_mean = 77.4
# daily_mean = 81.9

# %%
dat1 = [78,75.2,71.4,71.3,64.1,71.4,64,88.4,65.6,70.8,74.9,80.4]
dat2 = [91.1,110.9]

import scipy.stats
scipy.stats.f_oneway(dat1, dat2)
# Out:
# F_onewayResult(statistic=21.591390311017186, pvalue=0.0005636869341335554)

# %%
import scipy.stats
# rest
data1 = [88.9,112.8] # 7,12
data2 = [75.2,77.8,67.9,56.7,66.6,62.2,59.5,92,67.2,63.1,78.6,77.4]
print(scipy.stats.f_oneway(dat1, dat2))

# daily
data1 = [62.9] #5
data2 = [79.4,73.3,64,75.9,92.2,86.5,109.7] #1,3,4,6,7,11,12
data3 = [73.9,67,64.8,74.8,72.5,81.9] #2,8,13,14,15,17
print(scipy.stats.f_oneway(dat1,dat2,data3))
print(scipy.stats.f_oneway(dat1,dat2))
print(scipy.stats.f_oneway(dat2,data3))
# Out:
# F_onewayResult(statistic=28.66792955881228, pvalue=0.000682366248357892)
# F_onewayResult(statistic=335.1103525494129, pvalue=6.546138127779366e-12)
# F_onewayResult(statistic=28.66792955881228, pvalue=0.000682366248357892)
# F_onewayResult(statistic=392.443473998484, pvalue=2.355710136450305e-09)

# %% [markdown]
# ### fig

# %%
for i in range(len(date)):
  id = i+1
  print('ID '+str(id))
  h = heartrates[i]
  print(len(h))
  for j in date[i]:
    h = heartrates[i]
    h = h[h['startTimeInSeconds']==j].reset_index()
    print('startTimeInSeconds = '+str(j))
    print('mean = '+str(h['heartrate'].mean()))
    print('len = '+str(len(h)))
    plt.plot(h['heartrate'],label='heartrate')
    plt.axvline(x=1680,color='black')
    plt.axvline(x=3600,color='black')
    plt.axhline(y=50,color='r')
    plt.axhline(y=70,color='r')
    plt.axhline(y=100,color='r')
    plt.legend(loc='best')
    plt.show()
# Out:
# ID 1
# 13972
# startTimeInSeconds = 1650384000
# mean = 77.98541666666667
# len = 5760
# startTimeInSeconds = 1650470400
# mean = 75.87430555555555
# len = 5760
# startTimeInSeconds = 1650556800
# mean = 64.3132137030995
# len = 2452
# ID 2
# 11112
# startTimeInSeconds = 1651507200
# mean = 75.19606465214336
# len = 5692
# startTimeInSeconds = 1651593600
# mean = 78.0789667896679
# len = 5420
# ID 3
# 33436
# startTimeInSeconds = 1650643200
# mean = 71.49513888888889
# len = 5760
# startTimeInSeconds = 1650816000
# mean = 71.84169884169884
# len = 5180
# startTimeInSeconds = 1650902400
# mean = 67.57737627651218
# len = 5092
# startTimeInSeconds = 1650729600
# mean = 69.71666666666667
# len = 5760
# startTimeInSeconds = 1650988800
# mean = 73.79513888888889
# len = 5760
# startTimeInSeconds = 1651161600
# mean = 71.04545454545455
# len = 176
# startTimeInSeconds = 1651075200
# mean = 66.49124036440084
# len = 5708
# ID 4
# 9016
# startTimeInSeconds = 1651507200
# ...

# %%
# Out:
# 4.0

# %% [markdown]
# # stress

# %%
stresslevel=stresslevel[['id','startTimeInSeconds','time','timeOffsetStressLevelValues']]
# stresslevel

# %%
stresslevel = stresslevel.drop_duplicates()

# %%
stresslevel1 = stresslevel[stresslevel['id']==1].reset_index()
stresslevel2 = stresslevel[stresslevel['id']==2].reset_index()
stresslevel3 = stresslevel[stresslevel['id']==3].reset_index()
stresslevel4 = stresslevel[stresslevel['id']==4].reset_index()
stresslevel5 = stresslevel[stresslevel['id']==5].reset_index()
stresslevel6 = stresslevel[stresslevel['id']==6].reset_index()
stresslevel7 = stresslevel[stresslevel['id']==7].reset_index()
stresslevel8 = stresslevel[stresslevel['id']==8].reset_index()
stresslevel9 = stresslevel[stresslevel['id']==9].reset_index()
stresslevel10 = stresslevel[stresslevel['id']==10].reset_index()
stresslevel11 = stresslevel[stresslevel['id']==11].reset_index()
stresslevel12 = stresslevel[stresslevel['id']==12].reset_index()
stresslevel13 = stresslevel[stresslevel['id']==13].reset_index()
stresslevel14 = stresslevel[stresslevel['id']==14].reset_index()
stresslevel15 = stresslevel[stresslevel['id']==15].reset_index()
stresslevel16 = stresslevel[stresslevel['id']==16].reset_index()
stresslevel17 = stresslevel[stresslevel['id']==17].reset_index()

# %%
stresslevels = [stresslevel1,stresslevel2,stresslevel3,stresslevel4,
        stresslevel5,stresslevel6,stresslevel7,stresslevel8,
        stresslevel9,stresslevel10,stresslevel11,stresslevel12,
        stresslevel13,stresslevel14,stresslevel15,stresslevel16,stresslevel17]

# %%
date=[]
date.append(list(set(stresslevel1['startTimeInSeconds'])))
date.append(list(set(stresslevel2['startTimeInSeconds'])))
date.append(list(set(stresslevel3['startTimeInSeconds'])))
date.append(list(set(stresslevel4['startTimeInSeconds'])))
date.append(list(set(stresslevel5['startTimeInSeconds'])))
date.append(list(set(stresslevel6['startTimeInSeconds'])))
date.append(list(set(stresslevel7['startTimeInSeconds'])))
date.append(list(set(stresslevel8['startTimeInSeconds'])))
date.append(list(set(stresslevel9['startTimeInSeconds'])))
date.append(list(set(stresslevel10['startTimeInSeconds'])))
date.append(list(set(stresslevel11['startTimeInSeconds'])))
date.append(list(set(stresslevel12['startTimeInSeconds'])))
date.append(list(set(stresslevel13['startTimeInSeconds'])))
date.append(list(set(stresslevel14['startTimeInSeconds'])))
date.append(list(set(stresslevel15['startTimeInSeconds'])))
date.append(list(set(stresslevel16['startTimeInSeconds'])))
date.append(list(set(stresslevel17['startTimeInSeconds'])))

# %% [markdown]
# ### fig

# %%
for i in range(len(date)):
  id = i+1
  print('ID '+str(id))
  h = stresslevels[i]
  # print(len(date[i]))
  mean = []
  for j in date[i]:
    h = stresslevels[i]
    h = h[h['startTimeInSeconds']==j].reset_index()
    # print('startTimeInSeconds = '+str(j))
    if len(h)>=480:
      # print('mean = '+str(round(h['timeOffsetStressLevelValues'].mean(),1)))
      # print('len = '+str(len(h)))
      mean.append(round(h['timeOffsetStressLevelValues'].mean(),1))
  mean = [i for i in mean if i>=5]
  print('num = '+str(len(mean)))
  print('id = '+str(i+1)+' 平均壓力 '+str(sum(mean)/len(mean)))

# %%
data1 = [15.3,18.6,17.5,17.7]
data2 = [20.8,21.1,21.6,24.46,21.5,22.8]
data3 = [25,28.4,25.9,28.5]
data4 = [34.7,35.6,36.1]

import scipy.stats
scipy.stats.f_oneway(dat1, dat2, data3 ,data4)
# Out:
# F_onewayResult(statistic=106.41757629488268, pvalue=2.12005221570444e-09)

# %%
print(scipy.stats.f_oneway(dat1, dat2))
print(scipy.stats.f_oneway(dat3, dat2))
print(scipy.stats.f_oneway(dat3, dat4))
# Out:
# F_onewayResult(statistic=28.66792955881228, pvalue=0.000682366248357892)
# F_onewayResult(statistic=24.652748573358682, pvalue=0.001099764065530976)
# F_onewayResult(statistic=59.68480000000025, pvalue=0.0005803369216817406)
