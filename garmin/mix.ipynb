# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from glob import glob
import pandas as pd

files = glob('/content/drive/MyDrive/碩一下/多變量分析/data/daily/id/*.csv')
df = pd.concat((pd.read_csv(file)for file in files), ignore_index=True)
df.to_csv('/content/drive/MyDrive/碩一下/多變量分析/data/merge/daily.csv',index=False)

# %%
files = glob('/content/drive/MyDrive/碩一下/多變量分析/data/heartrate/id/*.csv')
df = pd.concat((pd.read_csv(file)for file in files), ignore_index=True)
df.to_csv('/content/drive/MyDrive/碩一下/多變量分析/data/merge/heartrate.csv',index=False)

# %%
files = glob('/content/drive/MyDrive/碩一下/多變量分析/data/epoch/id/*.csv')
df = pd.concat((pd.read_csv(file)for file in files), ignore_index=True)
df.to_csv('/content/drive/MyDrive/碩一下/多變量分析/data/merge/epoch.csv',index=False)

# %%
files = glob('/content/drive/MyDrive/碩一下/多變量分析/data/act/id/*.csv')
df = pd.concat((pd.read_csv(file)for file in files), ignore_index=True)
df.to_csv('/content/drive/MyDrive/碩一下/多變量分析/data/merge/act.csv',index=False)

# %%
files = glob('/content/drive/MyDrive/碩一下/多變量分析/data/sleep/id/*.csv')
df = pd.concat((pd.read_csv(file)for file in files), ignore_index=True)
df.to_csv('/content/drive/MyDrive/碩一下/多變量分析/data/merge/sleep.csv',index=False)

# %%
files = glob('/content/drive/MyDrive/碩一下/多變量分析/data/sleeplevel/id/*.csv')
df = pd.concat((pd.read_csv(file)for file in files), ignore_index=True)
df.to_csv('/content/drive/MyDrive/碩一下/多變量分析/data/merge/sleeplevel.csv',index=False)

# %%
files = glob('/content/drive/MyDrive/碩一下/多變量分析/data/stress/id/*.csv')
df = pd.concat((pd.read_csv(file)for file in files), ignore_index=True)
df.to_csv('/content/drive/MyDrive/碩一下/多變量分析/data/merge/stress.csv',index=False)

# %%
files = glob('/content/drive/MyDrive/碩一下/多變量分析/data/stresslevel/id/*.csv')
df = pd.concat((pd.read_csv(file)for file in files), ignore_index=True)
df.to_csv('/content/drive/MyDrive/碩一下/多變量分析/data/merge/stresslevel.csv',index=False)
